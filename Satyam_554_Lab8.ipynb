# %% [markdown]
# <a href="https://colab.research.google.com/github/SJhawar1010/NLP/blob/main/Satyam_554_Lab8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd
import numpy as np
import scipy.stats as stats
from sklearn.preprocessing import StandardScaler, LabelEncoder
from tensorflow.keras.utils import to_categorical
from sklearn.model_selection import train_test_split

# %%
data=pd.read_csv('/content/drive/MyDrive/NLP Datasets/seattle-weather.csv')
data.head()
# Out:
#          date  precipitation  temp_max  temp_min  wind  weather
# 0  2012-01-01            0.0      12.8       5.0   4.7  drizzle
# 1  2012-01-02           10.9      10.6       2.8   4.5     rain
# 2  2012-01-03            0.8      11.7       7.2   2.3     rain
# 3  2012-01-04           20.3      12.2       5.6   4.7     rain
# 4  2012-01-05            1.3       8.9       2.8   6.1     rain

# %%
def drop_outlier(data,col_name):
    z= np.abs(stats.zscore(col_name))
    data.drop(data.index[np.where(abs(z)>2.5)],inplace=True)
drop_outlier(data,data['precipitation'])
drop_outlier(data,data['temp_max'])
drop_outlier(data,data['temp_min'])
drop_outlier(data,data['wind'])

# %%
data=data.drop(columns='date')
sc=StandardScaler()

# %%
for i in data.drop(columns='weather').columns:
    data[i]=sc.fit_transform(data[[i]])
data.head()
# Out:
#    precipitation  temp_max  temp_min      wind  weather
# 0      -0.503221 -0.540252 -0.679922  1.265942  drizzle
# 1       2.239635 -0.840696 -1.123174  1.108110     rain
# 2      -0.301911 -0.690474 -0.236670 -0.628046     rain
# 4      -0.176092 -1.072858 -1.123174  2.370769     rain
# 5       0.125874 -1.687403 -1.244060 -0.706962     rain

# %%
X=data.drop(columns='weather')
le=LabelEncoder()
Y=le.fit_transform(data['weather'])
Y= to_categorical(Y)
X_train,X_val,Y_train,Y_val=train_test_split(X,Y,stratify=Y,test_size=0.2)

# %%
from tensorflow.keras.layers import LSTM, Dense, Embedding, Dropout, Input
from tensorflow.keras.models import Sequential
model=Sequential()
model.add(Input(shape=(X_train.shape[1],1)))
model.add(LSTM(32, activation='relu',return_sequences=True))
model.add(Dropout(0.2))
model.add(LSTM(64, activation='relu',return_sequences=True))
model.add(Dropout(0.2))
model.add(LSTM(128, activation='relu'))
model.add(Dropout(0.2))
model.add(Dense(5, activation='softmax'))

# %%
model.compile(loss='categorical_crossentropy', metrics=['accuracy'], optimizer='adam')

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 4, 32)             4352
#
#  dropout (Dropout)           (None, 4, 32)             0
#
#  lstm_1 (LSTM)               (None, 4, 64)             24832
#
#  dropout_1 (Dropout)         (None, 4, 64)             0
#
#  lstm_2 (LSTM)               (None, 128)               98816
#
#  dropout_2 (Dropout)         (None, 128)               0
#
#  dense (Dense)               (None, 5)                 645
#
# =================================================================
# Total params: 128645 (502.52 KB)
# Trainable params: 128645 (502.52 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
history=model.fit(X_train, Y_train, batch_size=32, epochs=50,validation_data=(X_val, Y_val))
# Out:
# Epoch 1/50
# 35/35 [==============================] - 14s 84ms/step - loss: 1.4749 - accuracy: 0.4088 - val_loss: 1.1168 - val_accuracy: 0.4161
# Epoch 2/50
# 35/35 [==============================] - 1s 19ms/step - loss: 1.1385 - accuracy: 0.4252 - val_loss: 1.0934 - val_accuracy: 0.4161
# Epoch 3/50
# 35/35 [==============================] - 1s 18ms/step - loss: 1.1116 - accuracy: 0.4708 - val_loss: 1.0870 - val_accuracy: 0.4161
# Epoch 4/50
# 35/35 [==============================] - 1s 17ms/step - loss: 1.0879 - accuracy: 0.4836 - val_loss: 1.0518 - val_accuracy: 0.5620
# Epoch 5/50
# 35/35 [==============================] - 1s 18ms/step - loss: 1.0458 - accuracy: 0.5520 - val_loss: 0.9597 - val_accuracy: 0.6496
# Epoch 6/50
# 35/35 [==============================] - 1s 17ms/step - loss: 0.9340 - accuracy: 0.6715 - val_loss: 0.8075 - val_accuracy: 0.7153
# Epoch 7/50
# 35/35 [==============================] - 1s 17ms/step - loss: 0.7912 - accuracy: 0.7263 - val_loss: 0.6446 - val_accuracy: 0.8029
# Epoch 8/50
# 35/35 [==============================] - 1s 17ms/step - loss: 0
50
# 35/35 [==============================] - 1s 16ms/step - loss: 0.5248 - accuracy: 0.8330 - val_loss: 0.5189 - val_accuracy: 0.8431
# Epoch 33/50
# 35/35 [==============================] - 1s 16ms/step - loss: 0.5152 - accuracy: 0.8376 - val_loss: 0.4932 - val_accuracy: 0.8431
# Epoch 34/50
# 35/35 [==============================] - 1s 15ms/step - loss: 0.5079 - accuracy: 0.8349 - val_loss: 0.4997 - val_accuracy: 0.8431
# Epoch 35/50
# 35/35 [==============================] - 1s 17ms/step - loss: 0.5080 - accuracy: 0.8403 - val_loss: 0.4985 - val_accuracy: 0.8467
# Epoch 36/50
# 35/35 [==============================] - 1s 16ms/step - loss: 0.5041 - accuracy: 0.8422 - val_loss: 0.4994 - val_accuracy: 0.8394
# Epoch 37/50
# 35/35 [==============================] - 1s 16ms/step - loss: 0.5048 - accuracy: 0.8412 - val_loss: 0.4946 - val_accuracy: 0.8431
# Epoch 38/50
# 35/35 [==============================] - 1s 17ms/step - loss: 0.5044 - accuracy: 0.8458 - val_loss: 0.4918 - val_accuracy: 0.8467
# Epoch 39/50
# 35/35 [==============================] - 1s 17ms/step - loss: 0.5077 - accuracy: 0.8403 - val_loss: 0.4972 - val_accuracy: 0.8467
# Epoch 40/50
# 35/35 [==============================] - 1s 29ms/step - loss: 0.4956 - accuracy: 0.8412 - val_loss: 0.5038 - val_accuracy: 0.8431
# Epoch 41/50
# 35/35 [==============================] - 1s 27ms/step - loss: 0.4977 - accuracy: 0.8422 - val_loss: 0.4895 - val_accuracy: 0.8431
# Epoch 42/50
# 35/35 [==============================] - 1s 30ms/step - loss: 0.5067 - accuracy: 0.8394 - val_loss: 0.4922 - val_accuracy: 0.8431
# Epoch 43/50
# 35/35 [==============================] - 1s 27ms/step - loss: 0.5005 - accuracy: 0.8422 - val_loss: 0.4899 - val_accuracy: 0.8467
# Epoch 44/50
# 35/35 [==============================] - 1s 21ms/step - loss: 0.5045 - accuracy: 0.8412 - val_loss: 0.4878 - val_accuracy: 0.8467
# Epoch 45/50
# 35/35 [==============================] - 1s 16ms/step - loss: 0.5037 - accuracy: 0.8422 - val_loss: 0.4935 - val_accuracy: 0.8467
# Epoch 46/50
# 35/35 [==============================] - 1s 17ms/step - loss: 0.5069 - accuracy: 0.8449 - val_loss: 0.4909 - val_accuracy: 0.8467
# Epoch 47/50
# 35/35 [==============================] - 1s 17ms/step - loss: 0.5006 - accuracy: 0.8449 - val_loss: 0.4927 - val_accuracy: 0.8431
# Epoch 48/50
# 35/35 [==============================] - 1s 17ms/step - loss: 0.5025 - accuracy: 0.8403 - val_loss: 0.4892 - val_accuracy: 0.8504
# Epoch 49/50
# 35/35 [==============================] - 1s 16ms/step - loss: 0.4932 - accuracy: 0.8431 - val_loss: 0.4905 - val_accuracy: 0.8467
# Epoch 50/50
# 35/35 [==============================] - 1s 17ms/step - loss: 0.4979 - accuracy: 0.8403 - val_loss: 0.4943 - val_accuracy: 0.8504

# %%
import matplotlib.pyplot as plt
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(50)

# %%
plt.figure(figsize=(8, 8))
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')
plt.show()

# %%
plt.figure(figsize=(8, 8))
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %%
import nltk
from googletrans import Translator

# %%
def translate_text(text, source_lang, dest_lang):
    translator = Translator()
    translated = translator.translate(text, src=source_lang, dest=dest_lang)
    return translated.text

# %%
input_text = "Hello, My Name is Satyam Jhawar."
translated_text = translate_text(input_text,'english','bengali')
print("Translated Text:", translated_text)
# Out:
# Translated Text: হ্যালো, আমার নাম সত্যম ঝাওয়ার।
