# %% [markdown]
# <a href="https://colab.research.google.com/github/SJhawar1010/NLP/blob/main/Satyam_554_Lab2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np

# %%
text = ("🏏 Renowned for his cool and composed demeanor both on and off the cricket field, Mahendra Singh Dhoni, is affectionately known as Captain Cool. " +
        " He has been a linchpin in the success of the Indian Cricket Team. Born on 7th July 1981, Dhoni's leadership style, characterized by strategic acumen and unflinching resolve, has elevated India ❤❤❤ to new heights." +
        " His uncanny ability to read the game and make astute decisions under pressure has earned him the admiration of fans worldwide.  With a career that spans decades, Dhoni has become a symbol of resilience and excellence." +
        " 🌟 Whether orchestrating thrilling victories or marshaling the team through challenging times, Dhoni's legacy is etched in the annals of cricket history. " +
        " His leadership prowess isn't reflected just in cricket but resonates with those who admire his unwavering spirit. 🏆 As an iconic figure in the cricketing world, Dhoni's impact extends beyond the boundary lines. " +
        " In a world inundated with emails and phone numbers, the mention of Dhoni invokes a sense of pride and nostalgia among cricket enthusiasts. " +
        " His contributions to the Indian Cricket Team are indelible, and his story continues to inspire generations. " +
        " 🇮🇳 #DhoniForever. Millions of People around the globe won't ever stop supporting him. His EmailId is mynameisdhoni7@yahoo.com 🥳🥳🥳. ")

# %%
text
# Out:
# "🏏 Renowned for his cool and composed demeanor both on and off the cricket field, Mahendra Singh Dhoni, is affectionately known as Captain Cool.  He has been a linchpin in the success of the Indian Cricket Team. Born on 7th July 1981, Dhoni's leadership style, characterized by strategic acumen and unflinching resolve, has elevated India ❤❤❤ to new heights. His uncanny ability to read the game and make astute decisions under pressure has earned him the admiration of fans worldwide.  With a career that spans decades, Dhoni has become a symbol of resilience and excellence. 🌟 Whether orchestrating thrilling victories or marshaling the team through challenging times, Dhoni's legacy is etched in the annals of cricket history.  His leadership prowess isn't reflected just in cricket but resonates with those who admire his unwavering spirit. 🏆 As an iconic figure in the cricketing world, Dhoni's impact extends beyond the boundary lines.  In a world inundated with emails and phone numbers, the
# ...

# %%
import nltk
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
nltk.download('punkt')
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
tokens = word_tokenize(text)

# %%
stop_words = set(stopwords.words('english'))
filtered_tokens = [token for token in tokens if token.isalpha() and token.lower() not in stop_words]
unique_tokens_count = len(set(filtered_tokens))
print("Number of unique tokens:", unique_tokens_count)
unique_tokens = set(filtered_tokens)
print("Unique Tokens:", unique_tokens)
# Out:
# Number of unique tokens: 104
# ...

# %%
import string

# %%
punctuation_count = sum(1 for char in text if char in string.punctuation)
text_without_punctuation = ''.join(char for char in text if char not in string.punctuation)
print("Number of punctuation characters:", punctuation_count)
print("Text without punctuation:", text_without_punctuation)
# Out:
# Number of punctuation characters: 31
# ...

# %%
import matplotlib.pyplot as plt
from collections import Counter

# %%
stop_words = set(stopwords.words('english'))
stopwords_in_text = [token for token in tokens if token.lower() in stop_words]
stopwords_count = Counter(stopwords_in_text)

# %%
plt.bar(stopwords_count.keys(), stopwords_count.values())
plt.xlabel('Stopwords')
plt.ylabel('Frequency')
plt.title('Distribution of Stopwords in Text')
plt.xticks(rotation=45, ha='right')
plt.show()

# %%
stop_words = set(stopwords.words('english'))
filtered_tokens = [token for token in tokens if token.lower() not in stop_words]
text_without_stopwords = ' '.join(filtered_tokens)
print("Text without stopwords:", text_without_stopwords)
# Out:
# Text without stopwords: 🏏 Renowned cool composed demeanor cricket field , Mahendra Singh Dhoni , affectionately known Captain Cool . linchpin success Indian Cricket Team . Born 7th July 1981 , Dhoni 's leadership style , characterized strategic acumen unflinching resolve , elevated India ❤❤❤ new heights . uncanny ability read game make astute decisions pressure earned admiration fans worldwide . career spans decades , Dhoni become symbol resilience excellence . 🌟 Whether orchestrating thrilling victories marshaling team challenging times , Dhoni 's legacy etched annals cricket history . leadership prowess n't reflected cricket resonates admire unwavering spirit . 🏆 iconic figure cricketing world , Dhoni 's impact extends beyond boundary lines . world inundated emails phone numbers , mention Dhoni invokes sense pride nostalgia among cricket enthusiasts . contributions Indian Cricket Team indelible , story continues inspire generations . 🇮🇳 # DhoniForever . Millions People around globe
# ...

# %%
nltk.download('punkt')
nltk.download('averaged_perceptron_tagger')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# True

# %%
pos_tags = nltk.pos_tag(tokens)
pos_tags_count = Counter(tag for _, tag in pos_tags)

# %%
plt.bar(pos_tags_count.keys(), pos_tags_count.values())
plt.xlabel('POS Tags')
plt.ylabel('Frequency')
plt.title('Distribution of POS Tags in Text')
plt.xticks(rotation=45, ha='right')
plt.show()

# %%
from nltk.probability import FreqDist

# %%
freq_dist = FreqDist(tokens)
top_tokens = freq_dist.most_common(10)

# %%
plt.bar([token[0] for token in top_tokens], [token[1] for token in top_tokens])
plt.xlabel('Tokens')
plt.ylabel('Frequency')
plt.title('Top 10 Most Occurring Tokens in Text')
plt.xticks(rotation=45, ha='right')
plt.show()

# %%
from nltk import bigrams, trigrams, ngrams

# %%
bigrams_list = list(bigrams(tokens))
trigrams_list = list(trigrams(tokens))
quadgrams_list = list(ngrams(tokens, 4))

# %%
unique_bigrams = set(bigrams_list)
unique_trigrams = set(trigrams_list)
unique_quadgrams = set(quadgrams_list)

print("Number of unique bigrams:", len(unique_bigrams))
print("Number of unique trigrams:", len(unique_trigrams))
print("Number of unique quadgrams:", len(unique_quadgrams))
# Out:
# Number of unique bigrams: 224
# Number of unique trigrams: 232
# Number of unique quadgrams: 234

# %%
import re
from datetime import datetime

# %%
date_pattern = re.compile(r'\b(\d{1,2})[/-](\d{1,2})[/-](\d{4})\b')
matches = date_pattern.findall(text)

# %%
converted_dates = []
for match in matches:
    day, month, year = map(int, match)
    converted_date = datetime(year, month, day).strftime('%d-%m-%Y')
    converted_dates.append(converted_date)

# %%
for i in range(len(matches)):
    text = text.replace(matches[i][0], converted_dates[i], 1)

# %%
print("Original text:")
print(text)
# Out:
# Original text:
# ...

# %%
year_pattern = re.compile(r'\b\d{4}\b')
years_found = year_pattern.findall(text)

# %%
year_counts = {}
for year in years_found:
    if year in year_counts:
        year_counts[year] += 1
    else:
        year_counts[year] = 1

# %%
plt.bar(year_counts.keys(), year_counts.values())
plt.xlabel('Year')
plt.ylabel('Frequency')
plt.title('Distribution of Years in Text')
plt.show()

# %%
def is_valid_phone_number(phone_number):
    return phone_number.isdigit()

# %%
def remove_invalid_phone_numbers(text):
    phone_number_pattern = re.compile(r'\b(?:\+\d{1,2}\s?)?[-.\(\)\s\d]+\b')
    phone_numbers_found = phone_number_pattern.findall(text)
    for phone_number in phone_numbers_found:
        if not is_valid_phone_number(''.join(filter(str.isdigit, phone_number))):
            text = text.replace(phone_number, '')

    return text

# %%
text_without_invalid_phones = remove_invalid_phone_numbers(text)
print("Original Text:")
print(text)
print("\nText without Invalid Phone Numbers:")
print(text_without_invalid_phones)
# Out:
# Original Text:
# ...
